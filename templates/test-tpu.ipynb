# %% [markdown]
# # TPU Test Notebook
# Connect this notebook to a **TPU runtime** via the Colab extension before running.
#
# **How to connect:** Kernel selector → Select Another Kernel → Colab → New Colab Server → TPU

# %%
# Check TPU availability
import os
tpu_addr = os.environ.get('COLAB_TPU_ADDR', None)
if tpu_addr:
    print(f"TPU Address: {tpu_addr}")
else:
    print("No TPU detected. Ensure you selected a TPU runtime.")
# Out:
# No TPU detected. Ensure you selected a TPU runtime.

# %%
# Initialize TensorFlow TPU
import tensorflow as tf

try:
    resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(resolver)
    tf.tpu.experimental.initialize_tpu_system(resolver)
    strategy = tf.distribute.TPUStrategy(resolver)
    print(f"Number of TPU replicas: {strategy.num_replicas_in_sync}")
except Exception as e:
    print(f"TPU initialization failed: {e}")
# Out:
# TPU initialization failed: Please provide a TPU Name to connect to.
