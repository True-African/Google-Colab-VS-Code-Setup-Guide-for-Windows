# %% [markdown]
# # GPU Test Notebook
# Connect this notebook to a **GPU runtime** via the Colab extension before running.
#
# **How to connect:** Kernel selector → Select Another Kernel → Colab → New Colab Server → GPU → T4

# %%
# Check GPU availability
# !nvidia-smi
# Out:
# Wed Apr 15 21:07:06 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0             26W /   70W |     107MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Test PyTorch with GPU
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
    x = torch.rand(3, 3).cuda()
    print(f"Tensor on GPU: {x.device}")
# Out:
# CUDA available: True
# GPU Device: Tesla T4
# Tensor on GPU: cuda:0

# %%
# Test TensorFlow with GPU
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
print(f"GPU devices: {gpus}")
# Out:
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
